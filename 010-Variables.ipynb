# %% [markdown]
# ## Variables

# %% [markdown]
# ---
#
# ### What is that: a variable?

# %% [markdown]
# Variables are one of the fundamental building blocks of Python. A variable is like a tiny container where you store values and data, such as filenames, words, numbers, collections of words and numbers, and more.

# %% [markdown]
# ![](https://cdn.pixabay.com/photo/2016/09/14/20/48/birthday-1670415_960_720.png)

# %% [markdown]
# ---
#
# ### Assigning values to variables

# %% [markdown]
# The variable name will point to a value that you "assign" it. You might think about variable assignment like putting a value "into" the variable, as if the variable is a little box 🎁
#
# You assign a value to a variable with an equals `=` sign. In Python, a single equals sign `=` is the "assignment operator." (A double equals sign `==` is the "real" equals sign, see later.)
#
# Variables are of some "type". "Type" stands for the set of values, a variable may take.
#
# Python has 4 elementary data types: `integer` (int), `float`, `string` (str), and `boolean` (bool). (Later, we'll see so-called collection types, which may hold more than a single value.)

# %%
# integer type
new_variable = 100
print(new_variable)
print (type(new_variable))

# %% [markdown]
# The output "<class 'int'>" shows the type of the variable `new_variable`.

# %%
# float type
a = 1.0 
# Here, the variable 'a' is assigned the 'float' value 1.0.
# Float values are numbers with a decimal point.
print(a)
print (type(a))

# %%
# string type
different_variable = "I'm another variable!"
print(different_variable)
print(type(different_variable))

# %%
# boolean type
b = True
# Here, the variable 'a' is assigned the 'boolean' value True.
# Boolean values are either True or False.
print(b)
print (type(b))

# %% [markdown]
# ---
#
# ###  Jupyter Display vs `Print()`

# %% [markdown]
# We can check to see what's "inside" these variables by running a cell with the variable's name. This is one of the handiest features of a Jupyter notebook.
#
# Outside the Jupyter environment, you would need to use the `print()` function to display the variable.

# %%
new_variable

# %%
a

# %%
different_variable

# %%
b

# %% [markdown]
# Your turn!

# %%
#your_chosen_variable = ...
#your_chosen_variable

# %% [markdown]
# You can run the `print` function inside the Jupyter environment, too. This is sometimes useful because Jupyter will only display the last variable in a cell, while `print()` can display multiple variables.
#
# Additionally, Jupyter will display text with `\n` characters (which means "new line"), while `print()` will display the text appropriately formatted with new lines.

# %% [markdown]
# For example, with the `print()` function, each of the variables are printed, and the "The Yellow Wallpaper" is properly formatted with new lines.

# %%
full_text = "This is an example sentence\nfor variable assignment."
print(full_text)
full_text

# %% [markdown]
# ---
#
# ### Variable Names

# %% [markdown]
# #### Basics

# %% [markdown]
# Variable names can be as long or as short as you want, and they can include:
# - upper and lower-case letters (A-Z)
# - digits (0-9)
# - underscores (_)
#
# However, variable names *cannot* include:
# - ❌ other punctuation (-.!?@)
# - ❌ spaces ( )
# - ❌ a reserved Python word

# %% [markdown]
# #### Striving for Good Variable Names

# %% [markdown]
# As you start to code, you will almost certainly be tempted to use extremely short variables names like `f`. Your fingers will get tired. Your coffee will wear off. You will see other people using variables like `f`. You'll promise yourself that you'll definitely remember what `f` means. But you probably won't.
#
# So, resist the temptation of bad variable names! Clear and precisely-named variables will:
#
# * make your code more readable (both to yourself and others)
# * reinforce your understanding of Python and what's happening in the code
# * clarify and strengthen your thinking

# %% [markdown]
# **Example Python Code ❌ With Unclear Variable Names❌**

# %% [markdown]
# For the sake of illustration, here's some of our same word count Python code with poorly named variables. The code works exactly the same as our original code, but it's a lot harder to read.

# %%
import re
def sp(t):
    lt = t.lower()
    sw = re.split(r"\W+", lt)
    return sw

f = "./datasets/Texts/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt"
ft = open(f, encoding="utf-8").read()

words = sp(ft)
len(words)

# %% [markdown]
# **Example Python Code ✨ With Clearer Variable Names ✨**

# %%
def split_into_words(any_chunk_of_text):
    lowercase_text = any_chunk_of_text.lower()
    split_words = re.split(r"\W+", lowercase_text)
    return split_words

filepath_of_text = "./datasets/Texts/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt"
full_text = open(filepath_of_text, encoding="utf-8").read()

all_the_words = split_into_words(full_text)
len(all_the_words)

# %% [markdown]
# #### Off-Limits Names

# %% [markdown]
# The only variable names that are off-limits are names that are reserved by, or built into, the Python programming language itself — such as `print`, `True`, and `list`.
#
# This is not something to worry too much about. You'll know very quickly if a name is reserved by Python because it will show up in some color and often give you an error message.

# %%
True = "./texts/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt"

# %% [markdown]
# ---
#
# ### Re-Assigning Variables

# %% [markdown]
# Variable assignment does not set a variable in stone. You can later re-assign the same variable a different value.

# %% [markdown]
# For instance, I could re-assign `filepath_of_text` to the filepath for the lyrics of Beyonce's album *Lemonade* instead of Perkins-Gilman's "The Yellow Wallpaper."

# %%
filepath_of_text = "./datasets/Texts/Beyonce-Lemonade.txt"
print(filepath_of_text)
filepath_of_text = "./datasets/Texts/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt"
print(filepath_of_text)
# Out:
# ./datasets/Texts/Beyonce-Lemonade.txt
# ./datasets/Texts/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt

# %% [markdown]
# ---
#
# ### Your Turn

# %% [markdown]
# Ok now it's your turn to change some variables! First, pick a new text file from the list below:
# - `"./texts/Carly-Rae-Jepsen-Emotion.txt"`
# - `"./texts/Mitski-Puberty-2.txt"`
# - `"./texts/Dracula_Bram-Stoker.txt"`
# - `"./texts/Little-Women_Louisa-May-Alcott.txt"`
# - `"./texts/Alice-in-Wonderland_Lewis-Carroll.txt"`

# %% [markdown]
# ---
#
# ### Recap
#
# | Data Type       | Explanation          | Example  |
# | ------------- |:-------------:| -----:|
# | String     | Text | ```"lemonade"``` |
# | Integer     | Whole Numbers      |   ```40``` |
# | Float | Decimal Numbers      |   ```40.2``` |
# | Boolean | True/False     |   ```False``` |
