# %%
import pymongo
import json
import sys

# Replace the placeholder data with your Atlas connection string. Be sure it includes
# a valid username and password! Note that in a production environment,
# you should not store your password in plain-text here.

uri = "mongodb+srv://nluttenberger:dNZH5qX07imKzKQh@nlcluster.bgxka9h.mongodb.net/?retryWrites=true&w=majority&appName=nlCluster"

try:
  client = pymongo.MongoClient(uri)
# return a friendly error if a URI error is thrown 
except pymongo.errors.ConfigurationError:
  print("An Invalid URI host error was received. Is your Atlas host name correct in your connection string?")
  sys.exit(1)

# use/create a database and a collection
db = client.orphDB
orphs = db["orphs"]

# drop (delete) the collection in case it already exists
try:
  orphs.drop()  
# return a friendly error if an authentication error is thrown
except pymongo.errors.OperationFailure:
  print("An authentication error was received in response to the drop command. Is your username and password correct in your connection string?")
  sys.exit(1)

# collect ready orphs from the working copy folder
copies = []

file = "C:/Users/nlutt/Documents/Orpheana/06 orphs - working copies/1996-Holländer-Wagner-Nürnberg.json"
with open(file, 'r', encoding='utf-8') as f:
  orph = json.load(f)
copies.append(orph)

file = "C:/Users/nlutt/Documents/Orpheana/06 orphs - working copies/2000-Holländer-Wagner-Düsseldorf.json"
with open(file, 'r', encoding='utf-8') as f:
  orph = json.load(f)
copies.append(orph)

orphs.insert_many(copies)

query = {"articles": {"$elemMatch": {"author": "Petrika Ionesco"}}}
projection = {"articles.author": 1, "articles.text": 1,  "_id": 0}

corpus = orphs.find(query, projection)
print("Number of documents in corpus: ", orphs.count_documents(query))
for orph in corpus:
  for article in orph["articles"]: 
    if article["author"] == "Petrika Ionesco":
      print(article["text"])  
         
client.close()
# Out:
# Number of documents in corpus:  1
# ...
